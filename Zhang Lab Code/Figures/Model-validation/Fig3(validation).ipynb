# %%
############### LOADING DATA ###############

external_data_processed = pd.read_csv('/home/christianl/Zhang-Lab/Zhang Lab Data/Full data files/Liver_bulk_external.tsv', 
                              sep='\t', header=0, index_col=0)
