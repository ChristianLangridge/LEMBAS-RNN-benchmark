# %%
############### GENERATING PREDICTIONS ###############

# %run '/home/christianl/Zhang-Lab/Zhang Lab Code/Boilerplate_datahandling/Remote boilerplate/model_validation_predictions.py'
# Out:
# ...
# Generating x_val, y_val and model predictions
# ...
#
# [1/6] Loading external liver bulk validation data...
#    External data shape: (262, 30363)
#
# [2/6] Generating x_validation (TF features)...
#    Usable TF features: 1197
#    Present in validation data: 1195
#    Missing (filled with 0): 2
# /home/christianl/Zhang-Lab/Zhang Lab Code/Boilerplate_datahandling/Remote boilerplate/model_validation_predictions.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   x_validation[feature] = validation_dataset[feature]
# ...

# %%
############### LOADING DATA ###############
