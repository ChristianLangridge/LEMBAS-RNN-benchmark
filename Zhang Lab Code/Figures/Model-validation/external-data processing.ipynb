# %%
import pandas as pd

# %%
external_data = pd.read_csv('/home/christianl/Zhang-Lab/Zhang Lab Data/Full data files/Liver_bulk_external.tsv', 
                              sep='\t', header=0, index_col=0)

# %%
print(external_data.shape)
# Out:
# (262, 30363)

# %%
external_data.head()
# Out:
#             A1BG  A1BG-AS1      A1CF       A2M   A2M-AS1  A2ML1  A2ML1-AS1  \
# OTW294  2.963062  0.240223  2.231290  3.158103  0.247186    0.0        0.0
# LOT902  3.125270  0.129437  2.251477  2.922589  0.416911    0.0        0.0
# RFN819  2.996027  0.233613  2.104936  2.884730  0.226125    0.0        0.0
# KZR101  2.999254  0.216233  1.945738  3.049881  0.180971    0.0        0.0
# YRI137  2.869777  0.149030  1.899529  2.865920  0.052792    0.0        0.0
#
#         A2ML1-AS2   A3GALT2    A4GALT  ...    ZWILCH     ZWINT      ZXDA  \
# OTW294   0.000000  0.000000  0.376734  ...  0.415155  0.232271  0.715373
# LOT902   0.000000  0.052016  0.338910  ...  0.431989  0.309727  0.693042
# RFN819   0.126005  0.000000  0.182517  ...  0.296147  0.189384  0.621463
# KZR101   0.000000  0.000000  0.295016  ...  0.342525  0.209040  0.572782
# YRI137   0.000000  0.019764  0.236383  ...  0.309794  0.240899  0.481780
#
#             ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX     ZZEF1      ZZZ3
# OTW294  1.201223  1.074461  0.445677  1.355254  1.282763  1.134956  1.011250
# LOT902  1.227910  1.066560  0.235779  1.442671  1.184793  1.156173  0.971415
# RFN819  1.185049  1.020925  0.294205  1.293762  1.075448  1.075928  0.971219
# KZR101  0.950963  0.917913  0.118287  1.265277  1.138923  0.974909  0.825010
# YRI137  0.700034  0.805555  0.061530  1.233172  1.226912  0.915635  0.785191
#
# [5 rows x 30363 columns]
