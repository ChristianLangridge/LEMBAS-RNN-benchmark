# %%
############### SHAP VALUE GENERATION MLR/XGBRF ###############


# %run '/home/christianl/Zhang-Lab/Zhang Lab Code/Boilerplate_datahandling/Remote boilerplate/shap_generation.py'

# %%
############### SHAP VALUE GENERATION RNN ###############

# %run '/home/christianl/Zhang-Lab/Zhang Lab Code/Boilerplate_datahandling/Remote boilerplate/shap_generation_RNN.py'

# %%
############### SHAP LOADING-TESTING-PLOTTING CLASSES/FUNCTIONS ###############

# %run '/home/christianl/Zhang-Lab/Zhang Lab Code/Boilerplate_datahandling/Remote boilerplate/shap_value_test_load_plot.py'

# %%
############### RUN STEP  ###############

if __name__ == "__main__":
    BASE_PATH = "/home/christianl/Zhang-Lab/Zhang Lab Data/Saved SHAP values/gene_specific/baseline_shap_values_OPTIMIZED(FINAL-nsamples=262).npz"
    RNN_PATH = "/home/christianl/Zhang-Lab/Zhang Lab Data/Saved SHAP values/gene_specific/rnn_shap_values_OPTIMIZED(FINAL-nsamples=262).npz"
    
    if os.path.exists(BASE_PATH) and os.path.exists(RNN_PATH):
        pipeline = ShapAnalysisPipeline(BASE_PATH, RNN_PATH)
        pipeline.plot_benchmark_grid()
    else:
        print("⚠️ Files not found.")
# Out:
# --- Loading SHAP Data ---
# ✅ Loaded Models: ['MLR', 'XGBRFRegressor', 'RNN']
# Plotting ALB Sample #237
# Found text: '+0.16'
# Found text: '+0.06'
# Found text: '+0.05'
# Found text: '+0.04'
# Found text: '+0.23'
# Found text: '−0.04'
# Found text: '−0.04'
# Found text: '−0.03'
# Found text: '−0.03'
# Found text: '+0.7'
# Found text: '+0.51'
# Found text: '+0.04'
# Found text: '+0.03'
# Found text: '+0.02'
# Found text: '+0.02'
# Found text: '+0.02'
# Found text: '+0.02'
# Found text: '+0.14'
# Found text: '+0.11'
# Found text: '+0.09'
# Found text: '+0.09'
# Found text: '+0.21'
# Found text: '−0.22'
# Found text: '−0.11'
# Found text: '−0.08'
# Found text: '−0.08'
# Found text: '−0.08'
# Plotting AFP Sample #97
# Found text: '+0.08'
# Found text: '+0.06'
# Found text: '+0.06'
# Found text: '+0.05'
# Found text: '+0.29'
# Found text: '−0.06'
# Found text: '−0.06'
# Found text: '−0.05'
# Found text: '−0.05'
# Found text: '+0.11'
# Found text: '+0.03'
# Found text: '+0.03'
# Found text: '−0.19'
# Found text: '−0.05'
# Found text: '−0.05'
# Found text: '−0.04'
# Found text: '−0.03'
# Found text: '−0.07'
# Found text: '+0.07'
# Found text: '+0.07'
# Found text: '+0.06'
# Found text: '+0.05'
# Found text: '+0.88'
# Found text: '−0.2'
# Found text: '−0.13'
# Found text: '−0.08'
# Found text: '−0.06'
#
# ✅ Poster Figure saved to: /home/christianl/Zhang-Lab/Zhang Lab Code/Figures/SHAP integration /shap_benchmark_poster.png
