# %%
import xgboost as xgb

xgb.__version__
# Out:
# '3.1.2'

# %%
############### SHAP VALUE GENERATION MLR/XGBRF ###############


# %run '/home/christianl/Zhang-Lab/Zhang Lab Code/Boilerplate_datahandling/Remote boilerplate/shap_generation.py'

# %%
############### SHAP VALUE GENERATION RNN ###############

# %run '/home/christianl/Zhang-Lab/Zhang Lab Code/Boilerplate_datahandling/Remote boilerplate/shap_generation_RNN.py'
# Out:
# ================================================================================
# Loading Validation Data
# ================================================================================
# ✓ x_validation: (262, 1197)
# ✓ y_validation: (262, 16100)
# ✓ ALB at index 477
# ✓ AFP at index 364
#
# ================================================================================
# Loading RNN Model
# ================================================================================
# ======================================================================
# LOADING MODEL - EXACT TRAINING SCRIPT SEQUENCE
# ======================================================================
#
# 1. Loading checkpoint from: /home/christianl/Zhang-Lab/Zhang Lab Data/Saved models/RNN/uncentered_data_RNN/signaling_model.v1.pt
#
# 2. Loading network from: /home/christianl/Zhang-Lab/Zhang Lab Data/Full data files/network(full).tsv
#    Network shape: (1153904, 3)
#    Network columns: ['TF', 'Gene', 'Interaction']
#
# 3. Formatting network...
#
# 4. Using EXACT benchmark.py parameters
#    projection_amplitude_in: 1.2
#    projection_amplitude_out: 1.2
#    bionet_params: {'target_steps': 150, 'max_steps': 10, 'exp_factor': 50, 'tolerance': 1e-20, 'leak': 0.01}
#
# 5. Initializing model with DataFrames...
#    Input X_in shape: (262, 1197)
#    Input y_out shape: (262, 16100)
#   Filtered X_in: 1197 → 1197 features
#   Filtered y_out: 16100 → 16100 features
#    ✓ Model initialized (data automatically filtered)
#
# 6. Converting DataFrames to tensors...
#    ✓ Tensors created
#
# 7. Applying training settings...
#    ✓ Set input_layer.weights.requires_grad = False
#    ✓ Applied prescale_weights(target_radius=0.8)
#
# 8. Loading trained weights...
#    ✓ Weights loaded
#    ✓ Model set to eval mode
#
# ======================================================================
# ✅ MODEL LOADED SUCCESSFULLY
# ======================================================================
#
# Model ready for inference:
#   Input features: 1197
#   Output features: 16100
#   Total network nodes: 16371
# ✓ RNN loaded on CUDA
# 🔧 Patching model attributes for cuda...
# ✓ Model attributes patched manually.
# Verifying convergence at 100 steps...
# ✓ Forward pass check passed.
#
# ================================================================================
# Computing RNN SHAP (OPTIMIZED)
# ================================================================================
# ⚠️  Background: 5 (reduced from 25)
# ⚠️  Test samples: 10 (reduced from 50)
# ⚠️  Interpolation steps: 20 (reduced from 200 default)
# ⚠️  Strategy: One sample at a time with progress tracking
#
# ────────────────────────────────────────────────────────────────────────────────
# Processing ALB
# ────────────────────────────────────────────────────────────────────────────────
# Creating GradientExplainer...
# Computing SHAP for 10 samples (one at a time)...
# ALB:  20%|██        | 2/10 [00:01<00:05,  1.57it/s]
#   [2/10] - 0.6s/sample - ETA: 0.1 min
# ALB:  40%|████      | 4/10 [00:02<00:04,  1.50it/s]
#   [4/10] - 0.7s/sample - ETA: 0.1 min
# ALB:  60%|██████    | 6/10 [00:03<00:02,  1.62it/s]
#   [6/10] - 0.6s/sample - ETA: 0.0 min
# ALB:  80%|████████  | 8/10 [00:05<00:01,  1.64it/s]
#   [8/10] - 0.6s/sample - ETA: 0.0 min
# ALB: 100%|██████████| 10/10 [00:06<00:00,  1.50it/s]
#   [10/10] - 0.7s/sample - ETA: 0.0 min
# ✓ ALB complete in 0.1 minutes
#   Shape: (10, 1197, 1)
#   Expected: 4.3086
#
# ────────────────────────────────────────────────────────────────────────────────
# Processing AFP
# ────────────────────────────────────────────────────────────────────────────────
# Creating GradientExplainer...
# Computing SHAP for 10 samples (one at a time)...
# AFP:  20%|██        | 2/10 [00:00<00:03,  2.11it/s]
#   [2/10] - 0.5s/sample - ETA: 0.1 min
# AFP:  40%|████      | 4/10 [00:02<00:03,  1.87it/s]
#   [4/10] - 0.5s/sample - ETA: 0.1 min
# AFP:  60%|██████    | 6/10 [00:03<00:02,  1.72it/s]
#   [6/10] - 0.6s/sample - ETA: 0.0 min
# AFP:  80%|████████  | 8/10 [00:12<00:06,  3.26s/it]
#   [8/10] - 1.6s/sample - ETA: 0.1 min
# AFP: 100%|██████████| 10/10 [00:14<00:00,  1.43s/it]
#   [10/10] - 1.4s/sample - ETA: 0.0 min
# ✓ AFP complete in 0.2 minutes
#   Shape: (10, 1197, 1)
#   Expected: 0.8251
#
# ================================================================================
# Saving Results
# ================================================================================
# ✓ Saved to: /home/christianl/Zhang-Lab/Zhang Lab Data/Saved SHAP values/gene_specific/rnn_shap_values_OPTIMIZED(FINAL).npz
#
# ================================================================================
# COMPLETE
# ================================================================================
# Success: 2/2 genes
# Samples per gene: 10
#
# IMPORTANT NOTES:
# - This is a SUBSET (10/262 samples)
# - Sufficient for feature importance comparison
# - To compute more samples, increase RNN_TEST_SAMPLES incrementally

# %%
############### DIAGNOSTICS ###############

import torch
import subprocess

print(f"--- 1. PYTORCH INTERNALS ---")
print(f"PyTorch Version: {torch.__version__}")
print(f"PyTorch compiled for CUDA: {torch.version.cuda}")
print(f"Supported Architectures (Arch List): {torch.cuda.get_arch_list()}")

print(f"\n--- 2. HARDWARE & DRIVER ---")
if torch.cuda.is_available():
    major, minor = torch.cuda.get_device_capability(0)
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Your GPU Compute Capability: {major}.{minor}")
else:
    print("!! CUDA IS NOT AVAILABLE TO PYTORCH !!")

try:
    smi = subprocess.check_output(["nvidia-smi"]).decode("utf-8").split('\n')
    print(f"System Driver Info: {smi[2]}") # Shows Driver Version & Max supported CUDA
except Exception:
    print("Could not run nvidia-smi. Check if drivers are installed.")
# Out:
# --- 1. PYTORCH INTERNALS ---
# PyTorch Version: 2.10.0+cu128
# PyTorch compiled for CUDA: 12.8
# Supported Architectures (Arch List): ['sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90', 'sm_100', 'sm_120']
#
# --- 2. HARDWARE & DRIVER ---
# GPU: NVIDIA GeForce RTX 5080
# Your GPU Compute Capability: 12.0
# System Driver Info: | NVIDIA-SMI 570.172.08             Driver Version: 570.172.08     CUDA Version: 12.8     |
