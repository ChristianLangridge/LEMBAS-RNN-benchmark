# %%
import xgboost as xgb

xgb.__version__
# Out:
# '3.1.2'

# %%
# %run '/home/christianl/Zhang-Lab/Zhang Lab Code/Boilerplate_datahandling/Remote boilerplate/shap_generation.py'
# Out:
# ================================================================================
# STEP 1: Loading Validation Data
# ================================================================================
#
# ✓ x_validation shape: (262, 1197)
# ✓ y_validation shape: (262, 16100)
#
# ================================================================================
# STEP 2: Locating Genes of Interest
# ================================================================================
#
# ✓ Found ALB at global index 477
# ✓ Found AFP at global index 364
#
# ================================================================================
# STEP 3: Loading Trained Models
# ================================================================================
#
# Loading MLR model...
#   ✓ MLR loaded
#   Coefficient shape: (16100, 1197)
#   Intercept shape: (16100,)
#
# ────────────────────────────────────────────────────────────────────────────────
# Loading XGBRF models (Batch Structure)
# ────────────────────────────────────────────────────────────────────────────────
#   ✓ Ensemble loaded
#   Structure: List of 17 batch models
#   Batch size: 1000 genes per batch
#   Total gene capacity: 17000
#
#   ALB:
#     Global gene index: 477
#     Batch index: 0
#     Within-batch index: 477
#     ✓ Successfully extracted model
#     ✓ Test prediction successful: shape (5,)
#
#   AFP:
#     Global gene index: 364
#     Batch index: 0
#     Within-batch index: 364
#     ✓ Successfully extracted model
#     ✓ Test prediction successful: shape (5,)
#
#   ✓ Batch models purged from memory
#
# ⊗ RNN DISABLED (set ENABLE_RNN=True to compute)
#
# ================================================================================
# STEP 4: Computing Gene-Specific SHAP Values
# ================================================================================
#
#
# ────────────────────────────────────────────────────────────────────────────────
# Processing ALB (global index 477)
# ────────────────────────────────────────────────────────────────────────────────
#
# [ALB] Computing MLR SHAP values...
#   Test prediction: shape (5, 1), mean 4.8274
#   Creating LinearExplainer...
#   Computing SHAP values...
#   ✓ MLR SHAP shape: (262, 1197)
#   ✓ Expected value: 4.7768
#   ✓ Mean |SHAP|: 0.003323
#
# [ALB] Computing XGBRF SHAP values...
#   Test prediction: shape (5,), mean 4.7417
#   Creating TreeExplainer...
#   Computing SHAP values...
#   ✓ XGBRF SHAP shape: (262, 1197)
#   ✓ Expected value: 3.3472
#   ✓ Mean |SHAP|: 0.001178
#
# ────────────────────────────────────────────────────────────────────────────────
# Processing AFP (global index 364)
# ────────────────────────────────────────────────────────────────────────────────
#
# [AFP] Computing MLR SHAP values...
#   Test prediction: shape (5, 1), mean 0.5956
#   Creating LinearExplainer...
#   Computing SHAP values...
#   ✓ MLR SHAP shape: (262, 1197)
#   ✓ Expected value: 0.5129
#   ✓ Mean |SHAP|: 0.002892
#
# [AFP] Computing XGBRF SHAP values...
#   Test prediction: shape (5,), mean 0.5832
#   Creating TreeExplainer...
#   Computing SHAP values...
#   ✓ XGBRF SHAP shape: (262, 1197)
#   ✓ Expected value: 0.8452
#   ✓ Mean |SHAP|: 0.000649
#
# ================================================================================
# STEP 5: Saving Results
# ================================================================================
#
# ✓ Saved SHAP values to: /home/christianl/Zhang-Lab/Zhang Lab Data/Saved SHAP values/gene_specific/gene_specific_shap_values_validation.npz
#   File size: 5.92 MB
# ✓ Saved metadata to: /home/christianl/Zhang-Lab/Zhang Lab Data/Saved SHAP values/gene_specific/gene_specific_shap_metadata_validation.json
#
# ================================================================================
# ✓ Script Completed Successfully!
# ================================================================================
#
# Genes processed: ['ALB', 'AFP']
#
# Models computed:
#   MLR: 2/2 genes
#   XGBRF: 2/2 genes
#   RNN: 0/2 genes
#
# Output files:
#   1. /home/christianl/Zhang-Lab/Zhang Lab Data/Saved SHAP values/gene_specific/gene_specific_shap_values_validation.npz
#   2. /home/christianl/Zhang-Lab/Zhang Lab Data/Saved SHAP values/gene_specific/gene_specific_shap_metadata_validation.json
#
# ────────────────────────────────────────────────────────────────────────────────
# Next Steps:
# ────────────────────────────────────────────────────────────────────────────────
# 1. Run verify_shap_outputs.py to validate and visualize results
# 2. Set ENABLE_RNN=True to compute RNN SHAP values (~2-3 minutes)
# 3. Create publication-quality waterfall/beeswarm plots
# 4. Compare feature importance across models
